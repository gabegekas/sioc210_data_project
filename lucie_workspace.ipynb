# %%
# Import everything! 
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import time
import argopy
import gsw
import os

seasons = ['fall','winter','spring','summer']
filenames = ['data_'+season+'_small_area.csv' for season in seasons] # define file of interest
dates = [
    ['2023-10-01', '2023-12-31'],
    ['2023-01-01', '2023-03-31'],
    ['2023-04-01', '2023-06-30'],
    ['2023-07-01', '2023-09-30']
]

select=2 #0=fall, 1=winter, 2=spring, 3=summer
season=seasons[select]
filename=filenames[select] 
date=dates[select] 

max_pressure = 2000 # dbar

# %%
# Gabe's code to get data, save in csv, and plot temp
#LRmod : separated writing csv from plotting to reload argo data with new dates

def save_to_csv():
    print("Importing data...")
    t0 = time.time()
    lat_range = [15, 20]     # Latitude: 15°N to 20°N
    lon_range = [85, 90]   # Longitude: 85°E to 90°E
    ArgoSet = argopy.DataFetcher().region([lon_range[0], lon_range[1], lat_range[0], lat_range[1], 0, max_pressure, date[0], date[1]]) # Bay of Bengal
    print("Time to create DataFetcher variable : ", time.time() - t0)
    df_raw = ArgoSet.data.argo.point2profile().to_dataframe()
    print("Time to get data from DataFetcher : ", time.time() - t0)
    # Remove rows where temp is None
    df = df_raw.dropna(subset=['TEMP', 'PSAL', 'PRES'])
    #Save to csv
    df.to_csv(filename)

save_to_csv() #Uncomment to load new dataset to csv

def plot_temp_vs_depth(filename):
    df=pd.read_csv(filename)
    # Define the variables to work with:
    temp = np.array(df['TEMP'])
    pressure = np.array(df['PRES'])
    # print(df.columns)

    # Scatter data and add grid
    plt.scatter(temp, pressure, s=1)
    plt.grid(True)

    # Adding labels to the axes and title
    plt.xlabel('Temperature [C]')
    plt.ylabel('Pressure [dBar]')
    plt.title('Temperature Vs. Pressure')
    plt.ylim(0, 1000) #Comment to plot entire depth
    plt.gca().invert_yaxis()

    # plt.savefig('figures/temp_vs_depth.png')
    plt.show()

    return

plot_temp_vs_depth(filename)
# Out:
# Importing data...
# Time to create DataFetcher variable :  0.0020580291748046875
# Time to get data from DataFetcher :  0.9324820041656494

# %%
def load_csv(filepath):
    # Load the data from the CSV file
    data = pd.read_csv(filepath)
    data = data.dropna(subset=['PRES', 'TEMP', 'PSAL']) # drop rows with nan in pressure, temperature or salinity columns
    print("Number of rows in data:", data.shape[0])
    # Show the first few rows of the data to confirm it's loaded correctly
    # print(data.head())
    return data

def filter_one_float(data):
    # Filter data for one specific float (e.g., PLATFORM_NUMBER 2902766)
    float_data = data[data['PLATFORM_NUMBER'] == 2902766]

    # Sort by pressure (depth) if needed
    float_data = float_data.sort_values(by='PRES')

    # print(float_data.head())
    return float_data

# %%
# Calculate the means and stds of salinity, density (by first calculating density), and temp 
def calculate_mean_profiles(data):
    # Create arrays to store averaged values
    mean_salinity = []
    mean_density = []
    mean_temperature = []
    std_salinity = []
    std_density = []
    std_temperature = []
    filtered_depths = [] # To get rid of weird line

    # filter data by QC :
    for index, row in data.iterrows() :
        if row['PSAL_QC'] > 1 or row['TEMP_QC'] > 1 or row['PRES_QC'] > 1 :
            data.drop(index, inplace=True) # removes row

    
    # Group data by depth to ensure unique depth entries
    # Seems too work better than looking at unique values 
    grouped_data = data.groupby('PRES')
    # # Print all unique 'PRES' values from the original data
    # print("All unique 'PRES' values in data:")
    # print(sorted(data['PRES'].unique()))
    # # Iterate over each group in grouped_data to view the grouped 'PRES' values
    # print("Grouped 'PRES' values and their corresponding data:")
    # for pres_value, group in grouped_data:
    #     print(f"\n'PRES' = {pres_value}")
    #     print(group)

    # Loop over each unique depth in the grouped data
    for depth, depth_data in grouped_data:
        # Skip if depth_data is empty
        if depth_data.empty:
            # Append NaN values for missing data
            mean_salinity.append(np.nan)
            std_salinity.append(np.nan)
            mean_temperature.append(np.nan)
            std_temperature.append(np.nan)
            mean_density.append(np.nan)
            std_density.append(np.nan)
            filtered_depths.append(depth)
            continue

        # Salinity calculations
        mean_salinity.append(depth_data['PSAL'].mean())
        std_salinity.append(depth_data['PSAL'].std())
        
        # Temperature calculations
        mean_temperature.append(depth_data['TEMP'].mean())
        std_temperature.append(depth_data['TEMP'].std())
        
        # Density calculations (using gsw for in-situ density; should we be using potential instead?)
        # Uses same method as calculate_density function
        salinity = depth_data['PSAL'].values
        temperature = depth_data['TEMP'].values
        pressure = depth
        latitude = depth_data['LATITUDE'].iloc[0]  
        longitude = depth_data['LONGITUDE'].iloc[0]
        
        SA = gsw.SA_from_SP(salinity, pressure, longitude, latitude)
        CT = gsw.CT_from_t(SA, temperature, pressure)
        density = gsw.rho(SA, CT, pressure)
        
        mean_density.append(np.mean(density))
        std_density.append(np.std(density))
        
        # Append only unique depths
        filtered_depths.append(depth)

    return filtered_depths, mean_salinity, std_salinity, mean_temperature, std_temperature, mean_density, std_density

# %%
def calculate_density(float_data):
    # Calculate in-situ density using gsw 
    # Modifies the input dataframe directly by creating a new column 'DENSITY'

    # Sort by pressure (depth)
    float_data = float_data.sort_values(by='PRES')

    # Calculate Absolute Salinity (SA) and Conservative Temperature (CT)
    # Note: gsw expects salinity in Practical Salinity Units (PSU), temperature in degrees Celsius, and pressure in decibars.
    pressure = float_data['PRES'].values
    salinity = float_data['PSAL'].values
    temperature = float_data['TEMP'].values
    latitude = float_data['LATITUDE'].values[0]  # Assuming constant latitude for the float
    longitude = float_data['LONGITUDE'].values[0]  # Assuming constant longitude for the float

    # Calculate Absolute Salinity and Conservative Temperature
    SA = gsw.SA_from_SP(salinity, pressure, longitude, latitude)
    CT = gsw.CT_from_t(SA, temperature, pressure)

    # Calculate density (in-situ density) using the equation of state
    density = gsw.rho(SA, CT, pressure)

    return pressure, density

# %%
def create_single_plot(float_data, x_column, x_label, title):
    """
    General function to create a plot for a single float's data.

    Parameters:
    - float_data: DataFrame containing the data for a single float.
    - x_column: str, column name for the x-axis data (e.g., 'PSAL' for salinity, 'TEMP' for temperature).
    - x_label: str, label for the x-axis.
    - title: str, title for the plot.
    - color: str, color of the plot line.
    """
    # Determine y-axis (depth) and x-axis data
    y_data = float_data['PRES']
    x_data = float_data[x_column]

    # Plot data vs. Depth
    plt.figure(figsize=(8, 6))
    plt.plot(x_data, y_data, label=x_label)

    # Invert the y-axis so that the surface is at the top
    plt.gca().invert_yaxis()

    # Label the axes
    plt.xlabel(x_label)
    plt.ylabel('Pressure [dbar]')

    # Add a title
    plt.title(title)

    # Show the plot
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_avg_profile(unique_depths, mean_values, std_values, x_label, title):
    """
    General function to plot the average profile with standard deviation shading.

    Parameters:
    - unique_depths: list or array of depth values (y-axis).
    - mean_values: list or array of mean values for the variable (x-axis).
    - std_values: list or array of standard deviation values for the variable.
    - x_label: str, label for the x-axis (e.g., 'Salinity [PSU]', 'Temperature [C]', 'Density [kg/m^3]').
    - title: str, title for the plot.
    """
    plt.figure(figsize=(8, 6))
    plt.plot(mean_values, unique_depths, label=f'Mean {x_label}')
    plt.fill_betweenx(unique_depths, 
                      np.array(mean_values) - np.array(std_values), 
                      np.array(mean_values) + np.array(std_values), 
                      color='b', alpha=0.2, label=f'{x_label} Std Dev')
    
    plt.gca().invert_yaxis()  # Invert y-axis to show surface at the top
    plt.xlabel(x_label)
    plt.ylabel('Pressure [dbar]')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

def plot_scatter_all(data, x_column, y_column, x_label, title, alpha=0.1, point_size=5):
    """
    General function to plot all data points with transparency for clustering visibility.

    Parameters:
    - data: pandas DataFrame containing the dataset.
    - x_column: str, name of the column to plot on the x-axis (e.g., 'PSAL' for salinity).
    - y_column: str, name of the column to plot on the y-axis (e.g., 'PRES' for pressure).
    - x_label: str, label for the x-axis.
    - title: str, title for the plot.
    - color: str, color of the points.
    - alpha: float, transparency level for points (0 to 1).
    - point_size: int, size of each point in the scatter plot.
    """
    plt.figure(figsize=(8, 6))
    plt.scatter(data[x_column], data[y_column], alpha=alpha, edgecolor='none', s=point_size)

    plt.gca().invert_yaxis()
    plt.xlabel(x_label)
    plt.ylabel('Pressure [dbar]')
    plt.title(title)
    plt.grid(True)
    plt.show()

# %%
# Main function 

filepath = os.getcwd() + '/' + filename #changing filepath separator for Mac from \\ to /
all_data = load_csv(filepath)
one_float_data = filter_one_float(all_data)

unique_depths, mean_salinity, std_salinity, mean_temperature, std_temperature, mean_density, std_density = calculate_mean_profiles(all_data)

# Calculate density values
try :
    one_pressure_value, one_density_value = calculate_density(one_float_data)
except :
    pass

pressure_values, density_values = calculate_density(all_data)

# TO DO: Maybe change colors for the graphs? 

# Salinity plots
create_single_plot(one_float_data, x_column='PSAL', x_label='Salinity [PSU]', title='Salinity Profile for Float 2902766')
plot_avg_profile(unique_depths, mean_salinity, std_salinity, x_label='Salinity [PSU]', title='Average Salinity Profile Across All Floats')
plot_scatter_all(all_data, x_column='PSAL', y_column='PRES', x_label='Salinity [PSU]', title='Salinity Profile for All Data Points')

# Temperature plots
create_single_plot(one_float_data, x_column='TEMP', x_label='Temperature [deg C]', title='Temperature Profile for Float 2902766')
plot_avg_profile(unique_depths, mean_temperature, std_temperature, x_label='Temperature [deg C]', title='Average Temperature Profile Across All Floats')
plot_scatter_all(all_data, x_column='TEMP', y_column='PRES', x_label='Temperature [deg C]', title='Temperature Profile for All Data Points')

# Density plots
create_single_plot(pd.DataFrame({'DENSITY': one_density_value, 'PRES': one_pressure_value}), x_column='DENSITY', x_label='Density [kg/m^3]', title='Density Profile for Float 2902766')
plot_avg_profile(unique_depths, mean_density, std_density, x_label='Density [kg/m^3]', title='Average Density Profile Across All Floats')
plot_scatter_all(pd.DataFrame({'DENSITY': density_values, 'PRES': pressure_values}), x_column='DENSITY', y_column='PRES', x_label='Density [kg/m^3]', title='Density Profile for All Data Points')
# Out:
# Number of rows in data: 917
# All unique 'PRES' values in data:
# [0.0, 0.1, 0.2, 0.3, 0.4, 0.9, 1.0, 1.1, 1.2, 1.3, 1.8, 1.9, 2.0, 2.1, 2.3, 2.8, 2.9, 3.0, 3.1, 3.2, 3.9, 4.0, 4.1, 4.2, 4.3, 4.7, 4.8, 4.9, 5.0, 5.1, 5.3, 5.6, 5.7, 5.8, 5.9, 6.1, 6.4, 6.8, 6.9, 7.0, 7.5, 7.8, 7.9, 8.0, 8.1, 8.6, 8.8, 8.9, 9.0, 9.1, 9.3, 9.8, 9.9, 10.0, 10.3, 14.6, 15.2, 15.3, 15.4, 15.5, 15.6, 15.7, 25.1, 25.3, 25.4, 25.5, 25.8, 26.2, 34.9, 35.2, 35.3, 35.4, 35.6, 35.7, 45.0, 45.2, 45.4, 45.5, 45.7, 45.9, 46.0, 55.0, 55.1, 55.4, 55.5, 55.7, 56.0, 56.2, 64.8, 65.0, 65.1, 65.2, 65.3, 65.6, 65.7, 74.9, 75.0, 75.3, 75.6, 75.7, 75.9, 84.8, 84.9, 85.0, 85.3, 85.4, 85.6, 85.9, 86.0, 95.1, 95.3, 95.4, 95.6, 95.9, 105.0, 105.1, 105.3, 105.4, 105.6, 105.8, 115.1, 115.5, 115.6, 115.7, 115.8, 125.1, 125.3, 125.5, 125.6, 125.8, 126.4, 135.2, 135.3, 135.4, 135.6, 135.7, 144.9, 145.0, 145.3, 145.5, 145.6, 146.0, 146.3, 154.9, 155.2, 155.3, 155.4, 155.5, 155.6, 156.1, 165.0, 165.2, 165.4, 165.5, 165.6, 165.8, 165.9, 174.9, 175.1, 175.2, 175.3, 175.5, 175.6, 175.7, 176.0, 185.0, 185.1, 185.2, 185.3, 185.5, 185.6, 186.3, 195.0, 195.1, 195.3, 195.4, 195.5, 195.6, 195.7, 212.3, 212.4, 212.5, 212.6, 212.8, 213.0, 213.2, 213.5, 237.2, 237.5, 237.6, 237.7, 238.0, 262.5, 262.6, 262.7, 262.9, 263.0, 263.4, 287.2, 287.6, 287.7, 287.9, 288.0, 288.1, 288.6, 312.6, 312.7, 312.8, 313.0, 313.1, 313.3, 313.4, 314.0, 314.3, 337.5, 337.6, 337.8, 337.9, 338.7, 338.9, 362.4, 362.5, 362.6, 362.7, 362.8, 362.9, 363.0, 363.1, 364.1, 387.5, 387.6, 387.7, 387.8, 387.9, 388.0, 412.3, 412.4, 412.5, 412.6, 412.9, 437.5, 437.6, 437.7, 438.1, 438.2, 462.5, 462.6, 462.7, 462.8, 462.9, 463.0, 463.1, 487.6, 487.7, 487.8, 488.0, 488.2, 512.6, 512.8, 512.9, 513.0, 513.2, 537.4, 537.6, 537.8, 537.9, 538.0, 538.2, 562.5, 562.6, 562.7, 562.9, 563.0, 563.1, 587.4, 587.5, 587.8, 587.9, 588.0, 588.3, 589.1, 589.2, 612.5, 612.6, 612.8, 612.9, 613.1, 613.2, 637.7, 637.9, 638.2, 638.5, 639.0, 639.1, 639.2, 662.5, 662.7, 662.8, 663.0, 664.3, 687.5, 687.7, 687.8, 687.9, 688.0, 688.1, 712.5, 712.6, 712.8, 712.9, 713.0, 737.4, 737.7, 737.8, 738.0, 738.2, 762.4, 762.6, 762.8, 762.9, 763.0, 763.1, 787.5, 787.6, 787.7, 787.8, 788.0, 788.1, 788.4, 812.6, 812.7, 813.0, 813.1, 813.2, 813.3, 837.7, 837.8, 837.9, 838.0, 838.2, 862.6, 862.7, 862.8, 862.9, 863.1, 863.2, 887.4, 887.7, 887.9, 888.0, 888.2, 912.4, 912.7, 912.8, 912.9, 913.1, 913.4, 937.6, 937.7, 937.8, 937.9, 938.4, 962.7, 963.0, 963.1, 963.4, 963.5, 963.8, 963.9, 964.0, 964.4, 987.3, 987.4, 987.7, 987.9, 988.8, 989.2, 1012.5, 1012.6, 1012.7, 1012.8, 1013.1, 1037.5, 1037.6, 1037.7, 1037.8, 1037.9, 1062.4, 1062.7, 1062.8, 1062.9, 1063.0, 1087.5, 1087.7, 1087.8, 1088.0, 1088.1, 1088.3, 1112.5, 1112.6, 1112.7, 1112.8, 1112.9, 1113.0, 1113.1, 1113.2, 1137.4, 1137.6, 1137.8, 1137.9, 1138.3, 1162.5, 1162.7, 1162.9, 1163.0, 1163.3, 1187.5, 1187.6, 1187.7, 1187.8, 1187.9, 1188.2, 1188.3, 1212.4, 1212.5, 1212.6, 1212.7, 1212.9, 1213.1, 1237.4, 1237.6, 1237.7, 1237.9, 1238.4, 1262.4, 1262.5, 1262.6, 1262.9, 1263.0, 1263.1, 1263.2, 1264.7, 1287.7, 1287.8, 1288.1, 1288.3, 1288.5, 1288.6, 1288.8, 1289.1, 1312.6, 1312.7, 1312.8, 1312.9, 1313.1, 1313.6, 1314.5, 1337.6, 1337.7, 1337.8, 1337.9, 1338.1, 1362.6, 1362.7, 1362.8, 1362.9, 1363.0, 1363.1, 1387.6, 1387.8, 1387.9, 1412.5, 1412.7, 1412.8, 1413.0, 1413.1, 1437.3, 1437.5, 1437.7, 1437.8, 1438.1, 1462.3, 1462.4, 1462.6, 1462.8, 1462.9, 1463.0, 1487.4, 1487.5, 1487.8, 1488.0, 1488.1, 1488.4, 1512.4, 1512.6, 1512.8, 1512.9, 1513.9, 1537.4, 1537.5, 1537.6, 1537.7, 1537.9, 1538.1, 1538.2, 1562.6, 1562.7, 1562.8, 1562.9, 1563.2, 1563.3, 1587.9, 1588.0, 1588.1, 1588.2, 1588.4, 1589.0, 1589.1, 1612.7, 1612.8, 1612.9, 1613.0, 1613.2, 1613.3, 1614.2, 1614.4, 1637.6, 1637.8, 1638.0, 1638.2, 1638.5, 1639.4, 1662.3, 1662.6, 1662.7, 1662.9, 1663.1, 1687.7, 1687.9, 1688.3, 1712.4, 1712.6, 1712.7, 1712.8, 1713.0, 1737.6, 1737.7, 1737.8, 1738.0, 1738.1, 1762.6, 1762.7, 1762.8, 1763.0, 1763.1, 1763.2, 1787.4, 1787.5, 1787.8, 1787.9, 1788.0, 1788.1, 1788.2, 1812.5, 1812.6, 1812.8, 1812.9, 1813.1, ...
# Grouped 'PRES' values and their corresponding data:
#
# 'PRES' = 0.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 510       5         0           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 510            1   0.0         2.4        1  32.83408        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 510  29.917       0.002        1        1    15.876      87.45
#
#                     TIME
# 510  2023-05-23 21:33:51
#
# 'PRES' = 0.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 204       2         0           120         D         A          2902766
# 815       8         0           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 204            1   0.1         2.4        1  32.56425        0.01        1
# 815            1   0.1         2.4        1  33.53288        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 204  30.086       0.002        1        1    15.592     87.388
# 815  29.924       0.002        1        1    16.125     87.731
#
#                     TIME
# 204  2023-04-25 03:25:55
# 815  2023-06-21 15:33:50
#
# 'PRES' = 0.2
#    N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 0       0         0           118         D         A          2902766
#
#    POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 0            1   0.2         2.4        1  32.37203        0.01        1
#
#      TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 0  29.779       0.002        1        1    15.489     86.705
#
#                   TIME
# 0  2023-04-05 23:34:34
#
# 'PRES' = 0.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 102       1         0           119         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 102            1   0.3         2.4        1  32.50714        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 102  30.195       0.002        1        1    15.669     87.042
#
#                     TIME
# 102  2023-04-15 13:32:47
#
# 'PRES' = 0.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 306       3         0           121         D         A          2902766
# 408       4         0           122         D         A          2902766
# 612       6         0           124         D         A          2902766
# 714       7         0           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 306            1   0.4         2.4        1  32.34362        0.01        1
# 408            1   0.4         2.4        1  32.84874        0.01        1
# 612            1   0.4         2.4        1  32.54156        0.01        1
# 714            1   0.4         2.4        1  32.84756        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 306  31.201       0.002        1        1    15.456     87.650
# 408  29.088       0.002        1        1    15.652     87.637
# 612  30.512       0.002        1        1    16.062     87.385
# 714  29.980       0.002        1        1    16.120     87.492
#
#                     TIME
# 306  2023-05-04 17:39:25
# 408  2023-05-14 07:38:50
# 612  2023-06-02 11:31:50
# 714  2023-06-12 01:28:50
#
# 'PRES' = 0.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 103       1         1           119         D         A          2902766
# 511       5         1           123         D         A          2902766
# 613       6         1           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 103            1   0.9         2.4        1  32.49876        0.01        1
# 511            1   0.9         2.4        1  32.82996        0.01        1
# 613            1   0.9         2.4        1  32.54404        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 103  30.202       0.002        1        1    15.669     87.042
# 511  29.924       0.002        1        1    15.876     87.450
# 613  30.513       0.002        1        1    16.062     87.385
#
#                     TIME
# 103  2023-04-15 13:32:47
# 511  2023-05-23 21:33:51
# 613  2023-06-02 11:31:50
#
# 'PRES' = 1.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 205       2         1           120         D         A          2902766
# 307       3         1           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 205            1   1.0         2.4        1  32.56263        0.01        1
# 307            1   1.0         2.4        1  32.34200        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 205  30.066       0.002        1        1    15.592     87.388
# 307  31.202       0.002        1        1    15.456     87.650
#
#                     TIME
# 205  2023-04-25 03:25:55
# 307  2023-05-04 17:39:25
#
# 'PRES' = 1.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 1         0         1           118         D         A          2902766
# 816       8         1           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 1              1   1.1         2.4        1  32.36605        0.01        1
# 816            1   1.1         2.4        1  33.53093        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 1    29.798       0.002        1        1    15.489     86.705
# 816  29.926       0.002        1        1    16.125     87.731
#
#                     TIME
# 1    2023-04-05 23:34:34
# 816  2023-06-21 15:33:50
#
# 'PRES' = 1.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 409       4         1           122         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 409            1   1.2         2.4        1  32.8634        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 409  29.079       0.002        1        1    15.652     87.637
#
#                     TIME
# 409  2023-05-14 07:38:50
#
# 'PRES' = 1.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 715       7         1           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 715            1   1.3         2.4        1  32.84401        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 715  29.98       0.002        1        1     16.12     87.492
#
#                     TIME
# 715  2023-06-12 01:28:50
#
# 'PRES' = 1.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 512       5         2           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 512            1   1.8         2.4        1  32.83185        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 512  29.924       0.002        1        1    15.876      87.45
#
#                     TIME
# 512  2023-05-23 21:33:51
#
# 'PRES' = 1.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 104       1         2           119         D         A          2902766
# 206       2         2           120         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 104            1   1.9         2.4        1  32.50588        0.01        1
# 206            1   1.9         2.4        1  32.56988        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 104  30.195       0.002        1        1    15.669     87.042
# 206  30.039       0.002        1        1    15.592     87.388
#
#                     TIME
# 104  2023-04-15 13:32:47
# 206  2023-04-25 03:25:55
#
# 'PRES' = 2.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 2         0         2           118         D         A          2902766
# 308       3         2           121         D         A          2902766
# 614       6         2           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 2              1   2.0         2.4        1  32.36879        0.01        1
# 308            1   2.0         2.4        1  32.34301        0.01        1
# 614            1   2.0         2.4        1  32.54496        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 2    29.796       0.002        1        1    15.489     86.705
# 308  31.202       0.002        1        1    15.456     87.650
# 614  30.512       0.002        1        1    16.062     87.385
#
#                     TIME
# 2    2023-04-05 23:34:34
# 308  2023-05-04 17:39:25
# 614  2023-06-02 11:31:50
#
# 'PRES' = 2.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 410       4         2           122         D         A          2902766
# 817       8         2           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 410            1   2.1         2.4        1  32.85892        0.01        1
# 817            1   2.1         2.4        1  33.52815        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 410  29.076       0.002        1        1    15.652     87.637
# 817  29.928       0.002        1        1    16.125     87.731
#
#                     TIME
# 410  2023-05-14 07:38:50
# 817  2023-06-21 15:33:50
#
# 'PRES' = 2.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 716       7         2           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 716            1   2.3         2.4        1  32.84301        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 716  29.98       0.002        1        1     16.12     87.492
#
#                     TIME
# 716  2023-06-12 01:28:50
#
# 'PRES' = 2.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 513       5         3           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 513            1   2.8         2.4        1  32.83076        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 513  29.926       0.002        1        1    15.876      87.45
#
#                     TIME
# 513  2023-05-23 21:33:51
#
# 'PRES' = 2.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 207       2         3           120         D         A          2902766
# 615       6         3           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 207            1   2.9         2.4        1  32.57543        0.01        1
# 615            1   2.9         2.4        1  32.54704        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 207  30.023       0.002        1        1    15.592     87.388
# 615  30.513       0.002        1        1    16.062     87.385
#
#                     TIME
# 207  2023-04-25 03:25:55
# 615  2023-06-02 11:31:50
#
# 'PRES' = 3.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 3         0         3           118         D         A          2902766
# 411       4         3           122         D         A          2902766
# 818       8         3           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 3              1   3.0         2.4        1  32.36696        0.01        1
# 411            1   3.0         2.4        1  32.85810        0.01        1
# 818            1   3.0         2.4        1  33.52917        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 3    29.800       0.002        1        1    15.489     86.705
# 411  29.069       0.002        1        1    15.652     87.637
# 818  29.926       0.002        1        1    16.125     87.731
#
#                     TIME
# 3    2023-04-05 23:34:34
# 411  2023-05-14 07:38:50
# 818  2023-06-21 15:33:50
#
# 'PRES' = 3.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 105       1         3           119         D         A          2902766
# 309       3         3           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 105            1   3.1         2.4        1  32.52106        0.01        1
# 309            1   3.1         2.4        1  32.34308        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 105  30.175       0.002        1        1    15.669     87.042
# 309  31.202       0.002        1        1    15.456     87.650
#
#                     TIME
# 105  2023-04-15 13:32:47
# 309  2023-05-04 17:39:25
#
# 'PRES' = 3.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 717       7         3           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 717            1   3.2         2.4        1  32.84405        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 717  29.98       0.002        1        1     16.12     87.492
#
#                     TIME
# 717  2023-06-12 01:28:50
#
# 'PRES' = 3.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 4         0         4           118         D         A          2902766
# 208       2         4           120         D         A          2902766
# 412       4         4           122         D         A          2902766
# 616       6         4           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 4              1   3.9         2.4        1  32.36705        0.01        1
# 208            1   3.9         2.4        1  32.57838        0.01        1
# 412            1   3.9         2.4        1  32.87331        0.01        1
# 616            1   3.9         2.4        1  32.54697        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 4    29.801       0.002        1        1    15.489     86.705
# 208  30.016       0.002        1        1    15.592     87.388
# 412  29.031       0.002        1        1    15.652     87.637
# 616  30.512       0.002        1        1    16.062     87.385
#
#                     TIME
# 4    2023-04-05 23:34:34
# 208  2023-04-25 03:25:55
# 412  2023-05-14 07:38:50
# 616  2023-06-02 11:31:50
#
# 'PRES' = 4.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 106       1         4           119         D         A          2902766
# 310       3         4           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 106            1   4.0         2.4        1  32.59178        0.01        1
# 310            1   4.0         2.4        1  32.34513        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 106  30.077       0.002        1        1    15.669     87.042
# 310  31.201       0.002        1        1    15.456     87.650
#
#                     TIME
# 106  2023-04-15 13:32:47
# 310  2023-05-04 17:39:25
#
# 'PRES' = 4.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 819       8         4           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 819            1   4.1         2.4        1  33.53116        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 819  29.923       0.002        1        1    16.125     87.731
#
#                     TIME
# 819  2023-06-21 15:33:50
#
# 'PRES' = 4.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 514       5         4           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 514            1   4.2         2.4        1  32.83099        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 514  29.932       0.002        1        1    15.876      87.45
#
#                     TIME
# 514  2023-05-23 21:33:51
#
# 'PRES' = 4.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 718       7         4           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 718            1   4.3         2.4        1  32.84502        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 718  29.979       0.002        1        1     16.12     87.492
#
#                     TIME
# 718  2023-06-12 01:28:50
#
# 'PRES' = 4.7
#    N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 5       0         5           118         D         A          2902766
#
#    POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 5            1   4.7         2.4        1  32.36679        0.01        1
#
#      TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 5  29.799       0.002        1        1    15.489     86.705
#
#                   TIME
# 5  2023-04-05 23:34:34
#
# 'PRES' = 4.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 107       1         5           119         D         A          2902766
# 413       4         5           122         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 107            1   4.8         2.4        1  32.61028        0.01        1
# 413            1   4.8         2.4        1  32.87938        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 107  30.021       0.002        1        1    15.669     87.042
# 413  29.027       0.002        1        1    15.652     87.637
#
#                     TIME
# 107  2023-04-15 13:32:47
# 413  2023-05-14 07:38:50
#
# 'PRES' = 4.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 209       2         5           120         D         A          2902766
# 311       3         5           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 209            1   4.9         2.4        1  32.58118        0.01        1
# 311            1   4.9         2.4        1  32.34990        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 209  30.009       0.002        1        1    15.592     87.388
# 311  31.198       0.002        1        1    15.456     87.650
#
#                     TIME
# 209  2023-04-25 03:25:55
# 311  2023-05-04 17:39:25
#
# 'PRES' = 5.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 515       5         5           123         D         A          2902766
# 617       6         5           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 515            1   5.0         2.4        1  32.83297        0.01        1
# 617            1   5.0         2.4        1  32.54709        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 515  29.932       0.002        1        1    15.876     87.450
# 617  30.513       0.002        1        1    16.062     87.385
#
#                     TIME
# 515  2023-05-23 21:33:51
# 617  2023-06-02 11:31:50
#
# 'PRES' = 5.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 820       8         5           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 820            1   5.1         2.4        1  33.53205        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 820  29.92       0.002        1        1    16.125     87.731
#
#                     TIME
# 820  2023-06-21 15:33:50
#
# 'PRES' = 5.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 719       7         5           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 719            1   5.3         2.4        1  32.84509        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 719  29.979       0.002        1        1     16.12     87.492
#
#                     TIME
# 719  2023-06-12 01:28:50
#
# 'PRES' = 5.6
#    N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 6       0         6           118         D         A          2902766
#
#    POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 6            1   5.6         2.4        1  32.36697        0.01        1
#
#      TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 6  29.803       0.002        1        1    15.489     86.705
#
#                   TIME
# 6  2023-04-05 23:34:34
#
# 'PRES' = 5.7
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 108       1         6           119         D         A          2902766
# 312       3         6           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 108            1   5.7         2.4        1  32.60876        0.01        1
# 312            1   5.7         2.4        1  32.34840        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 108  29.986       0.002        1        1    15.669     87.042
# 312  31.202       0.002        1        1    15.456     87.650
#
#                     TIME
# 108  2023-04-15 13:32:47
# 312  2023-05-04 17:39:25
#
# 'PRES' = 5.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 210       2         6           120         D         A          2902766
# 414       4         6           122         D         A          2902766
# 618       6         6           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 210            1   5.8         2.4        1  32.58010        0.01        1
# 414            1   5.8         2.4        1  32.87545        0.01        1
# 618            1   5.8         2.4        1  32.56094        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 210  30.006       0.002        1        1    15.592     87.388
# 414  29.026       0.002        1        1    15.652     87.637
# 618  30.511       0.002        1        1    16.062     87.385
#
#                     TIME
# 210  2023-04-25 03:25:55
# 414  2023-05-14 07:38:50
# 618  2023-06-02 11:31:50
#
# 'PRES' = 5.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 516       5         6           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 516            1   5.9         2.4        1  32.83228        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 516  29.934       0.002        1        1    15.876      87.45
#
#                     TIME
# 516  2023-05-23 21:33:51
#
# 'PRES' = 6.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 821       8         6           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 821            1   6.1         2.4        1  33.53275        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 821  29.918       0.002        1        1    16.125     87.731
#
#                     TIME
# 821  2023-06-21 15:33:50
#
# 'PRES' = 6.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 720       7         6           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 720            1   6.4         2.4        1  32.84598        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 720  29.977       0.002        1        1     16.12     87.492
#
#                     TIME
# 720  2023-06-12 01:28:50
#
# 'PRES' = 6.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 211       2         7           120         D         A          2902766
# 415       4         7           122         D         A          2902766
# 517       5         7           123         D         A          2902766
# 619       6         7           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 211            1   6.8         2.4        1  32.58101        0.01        1
# 415            1   6.8         2.4        1  32.88041        0.01        1
# 517            1   6.8         2.4        1  32.83286        0.01        1
# 619            1   6.8         2.4        1  32.57196        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 211  30.004       0.002        1        1    15.592     87.388
# 415  28.999       0.002        1        1    15.652     87.637
# 517  29.933       0.002        1        1    15.876     87.450
# 619  30.512       0.002        1        1    16.062     87.385
#
#                     TIME
# 211  2023-04-25 03:25:55
# 415  2023-05-14 07:38:50
# 517  2023-05-23 21:33:51
# 619  2023-06-02 11:31:50
#
# 'PRES' = 6.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 7         0         7           118         D         A          2902766
# 109       1         7           119         D         A          2902766
# 313       3         7           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 7              1   6.9         2.4        1  32.36608        0.01        1
# 109            1   6.9         2.4        1  32.61010        0.01        1
# 313            1   6.9         2.4        1  32.34993        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 7    29.804       0.002        1        1    15.489     86.705
# 109  29.954       0.002        1        1    15.669     87.042
# 313  31.200       0.002        1        1    15.456     87.650
#
#                     TIME
# 7    2023-04-05 23:34:34
# 109  2023-04-15 13:32:47
# 313  2023-05-04 17:39:25
#
# 'PRES' = 7.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 822       8         7           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 822            1   7.0         2.4        1  33.53243        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 822  29.92       0.002        1        1    16.125     87.731
#
#                     TIME
# 822  2023-06-21 15:33:50
#
# 'PRES' = 7.5
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 721       7         7           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 721            1   7.5         2.4        1  32.8449        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 721  29.977       0.002        1        1     16.12     87.492
#
#                     TIME
# 721  2023-06-12 01:28:50
#
# 'PRES' = 7.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 212       2         8           120         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 212            1   7.8         2.4        1  32.58082        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 212  30.003       0.002        1        1    15.592     87.388
#
#                     TIME
# 212  2023-04-25 03:25:55
#
# 'PRES' = 7.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 416       4         8           122         D         A          2902766
# 823       8         8           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 416            1   7.9         2.4        1  32.88113        0.01        1
# 823            1   7.9         2.4        1  33.53230        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 416  28.995       0.002        1        1    15.652     87.637
# 823  29.932       0.002        1        1    16.125     87.731
#
#                     TIME
# 416  2023-05-14 07:38:50
# 823  2023-06-21 15:33:50
#
# 'PRES' = 8.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 314       3         8           121         D         A          2902766
# 518       5         8           123         D         A          2902766
# 620       6         8           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 314            1   8.0         2.4        1  32.35488        0.01        1
# 518            1   8.0         2.4        1  32.83684        0.01        1
# 620            1   8.0         2.4        1  32.57675        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 314  31.174       0.002        1        1    15.456     87.650
# 518  29.928       0.002        1        1    15.876     87.450
# 620  30.512       0.002        1        1    16.062     87.385
#
#                     TIME
# 314  2023-05-04 17:39:25
# 518  2023-05-23 21:33:51
# 620  2023-06-02 11:31:50
#
# 'PRES' = 8.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 8         0         8           118         D         A          2902766
# 110       1         8           119         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 8              1   8.1         2.4        1  32.36792        0.01        1
# 110            1   8.1         2.4        1  32.61291        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 8    29.802       0.002        1        1    15.489     86.705
# 110  29.921       0.002        1        1    15.669     87.042
#
#                     TIME
# 8    2023-04-05 23:34:34
# 110  2023-04-15 13:32:47
#
# 'PRES' = 8.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 722       7         8           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 722            1   8.6         2.4        1  32.84398        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 722  29.979       0.002        1        1     16.12     87.492
#
#                     TIME
# 722  2023-06-12 01:28:50
#
# 'PRES' = 8.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 213       2         9           120         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 213            1   8.8         2.4        1  32.58106        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 213  30.007       0.002        1        1    15.592     87.388
#
#                     TIME
# 213  2023-04-25 03:25:55
#
# 'PRES' = 8.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 9         0         9           118         D         A          2902766
# 417       4         9           122         D         A          2902766
# 621       6         9           124         D         A          2902766
# 824       8         9           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 9              1   8.9         2.4        1  32.36693        0.01        1
# 417            1   8.9         2.4        1  32.88234        0.01        1
# 621            1   8.9         2.4        1  32.59083        0.01        1
# 824            1   8.9         2.4        1  33.53297        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 9    29.803       0.002        1        1    15.489     86.705
# 417  28.974       0.002        1        1    15.652     87.637
# 621  30.516       0.002        1        1    16.062     87.385
# 824  29.926       0.002        1        1    16.125     87.731
#
#                     TIME
# 9    2023-04-05 23:34:34
# 417  2023-05-14 07:38:50
# 621  2023-06-02 11:31:50
# 824  2023-06-21 15:33:50
#
# 'PRES' = 9.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 111       1         9           119         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 111            1   9.0         2.4        1  32.61383        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 111  29.87       0.002        1        1    15.669     87.042
#
#                     TIME
# 111  2023-04-15 13:32:47
#
# 'PRES' = 9.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 315       3         9           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 315            1   9.1         2.4        1  32.35995        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 315  31.101       0.002        1        1    15.456      87.65
#
#                     TIME
# 315  2023-05-04 17:39:25
#
# 'PRES' = 9.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 519       5         9           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 519            1   9.3         2.4        1  32.86687        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 519  29.86       0.002        1        1    15.876      87.45
#
#                     TIME
# 519  2023-05-23 21:33:51
#
# 'PRES' = 9.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 214       2        10           120         D         A          2902766
# 622       6        10           124         D         A          2902766
# 723       7         9           125         D         A          2902766
# 825       8        10           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 214            1   9.8         2.4        1  32.58005        0.01        1
# 622            1   9.8         2.4        1  32.64133        0.01        1
# 723            1   9.8         2.4        1  32.84457        0.01        1
# 825            1   9.8         2.4        1  33.53090        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 214  30.006       0.002        1        1    15.592     87.388
# 622  30.521       0.002        1        1    16.062     87.385
# 723  29.978       0.002        1        1    16.120     87.492
# 825  29.926       0.002        1        1    16.125     87.731
#
#                     TIME
# 214  2023-04-25 03:25:55
# 622  2023-06-02 11:31:50
# 723  2023-06-12 01:28:50
# 825  2023-06-21 15:33:50
#
# 'PRES' = 9.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 112       1        10           119         D         A          2902766
# 418       4        10           122         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 112            1   9.9         2.4        1  32.61811        0.01        1
# 418            1   9.9         2.4        1  32.88263        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 112  29.798       0.002        1        1    15.669     87.042
# 418  28.970       0.002        1        1    15.652     87.637
#
#                     TIME
# 112  2023-04-15 13:32:47
# 418  2023-05-14 07:38:50
#
# 'PRES' = 10.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 10        0        10           118         D         A          2902766
# 316       3        10           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 10             1  10.0         2.4        1  32.36665        0.01        1
# 316            1  10.0         2.4        1  32.36127        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 10   29.803       0.002        1        1    15.489     86.705
# 316  31.080       0.002        1        1    15.456     87.650
#
#                     TIME
# 10   2023-04-05 23:34:34
# 316  2023-05-04 17:39:25
#
# 'PRES' = 10.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 520       5        10           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 520            1  10.3         2.4        1  32.89128        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 520  29.732       0.002        1        1    15.876      87.45
#
#                     TIME
# 520  2023-05-23 21:33:51
#
# 'PRES' = 14.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 317       3        11           121         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 317            1  14.6         2.4        1  32.48223        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 317  30.54       0.002        1        1    15.456      87.65
#
#                     TIME
# 317  2023-05-04 17:39:25
#
# 'PRES' = 15.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 826       8        11           126         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 826            1  15.2         2.4        1  33.5689        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 826  29.934       0.002        1        1    16.125     87.731
#
#                     TIME
# 826  2023-06-21 15:33:50
#
# 'PRES' = 15.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 215       2        11           120         D         A          2902766
# 419       4        11           122         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 215            1  15.3         2.4        1  32.58110        0.01        1
# 419            1  15.3         2.4        1  32.88743        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 215  30.002       0.002        1        1    15.592     87.388
# 419  28.918       0.002        1        1    15.652     87.637
#
#                     TIME
# 215  2023-04-25 03:25:55
# 419  2023-05-14 07:38:50
#
# 'PRES' = 15.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 11        0        11           118         D         A          2902766
# 113       1        11           119         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 11             1  15.4         2.4        1  32.42365        0.01        1
# 113            1  15.4         2.4        1  32.60262        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 11   29.833       0.002        1        1    15.489     86.705
# 113  29.442       0.002        1        1    15.669     87.042
#
#                     TIME
# 11   2023-04-05 23:34:34
# 113  2023-04-15 13:32:47
#
# 'PRES' = 15.5
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 623       6        11           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 623            1  15.5         2.4        1  32.65585        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 623  30.491       0.002        1        1    16.062     87.385
#
#                     TIME
# 623  2023-06-02 11:31:50
#
# 'PRES' = 15.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 724       7        10           125         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC   PSAL  PSAL_ERROR  PSAL_QC  \
# 724            1  15.6         2.4        1  32.91        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 724  30.017       0.002        1        1     16.12     87.492
#
#                     TIME
# 724  2023-06-12 01:28:50
#
# 'PRES' = 15.7
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 521       5        11           123         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 521            1  15.7         2.4        1  32.90636        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 521  29.54       0.002        1        1    15.876      87.45
#
#                     TIME
# 521  2023-05-23 21:33:51
#
# 'PRES' = 25.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 624       6        12           124         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 624            1  25.1         2.4        1  32.75077        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 624  30.361       0.002        1        1    16.062     87.385
#
#                     TIME
# 624  2023-06-02 11:31:50
#
# 'PRES' = 25.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 114       1        12           119         D         A          2902766
#
#      POSITION_QC  PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 114            1  25.3         2.4        1  32.6626        0.01        1
#
#        TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 114  28.881       0.002        1        1    15.669     87.042
#
#                     TIME
# 114  2023-04-15 13:32:47
#
# 'PRES' = 25.4
#     N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# ...
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 506            1  1912.4         2.4        1  34.7802        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 506  2.766       0.002        1        1    15.652     87.637
#
#                     TIME
# 506  2023-05-14 07:38:50
#
# 'PRES' = 1912.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 200       1        98           119         D         A          2902766
# 302       2        98           120         D         A          2902766
# 404       3        98           121         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 200            1  1912.6         2.4        1  34.78821        0.01        1
# 302            1  1912.6         2.4        1  34.78925        0.01        1
# 404            1  1912.6         2.4        1  34.78625        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 200  2.974       0.002        1        1    15.669     87.042
# 302  2.998       0.002        1        1    15.592     87.388
# 404  2.905       0.002        1        1    15.456     87.650
#
#                     TIME
# 200  2023-04-15 13:32:47
# 302  2023-04-25 03:25:55
# 404  2023-05-04 17:39:25
#
# 'PRES' = 1912.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 98        0        98           118         D         A          2902766
# 608       5        98           123         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 98             1  1912.8         2.4        1  34.78524        0.01        1
# 608            1  1912.8         2.4        1  34.78218        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 98   2.895       0.002        1        1    15.489     86.705
# 608  2.807       0.002        1        1    15.876     87.450
#
#                     TIME
# 98   2023-04-05 23:34:34
# 608  2023-05-23 21:33:51
#
# 'PRES' = 1912.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 710       6        98           124         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 710            1  1912.9         2.4        1  34.78922        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 710  2.976       0.002        1        1    16.062     87.385
#
#                     TIME
# 710  2023-06-02 11:31:50
#
# 'PRES' = 1913.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 811       7        97           125         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 811            1  1913.0         2.4        1  34.78724        0.01        1
#
#      TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 811  2.95       0.002        1        1     16.12     87.492
#
#                     TIME
# 811  2023-06-12 01:28:50
#
# 'PRES' = 1913.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 913       8        98           126         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 913            1  1913.2         2.4        1  34.78925        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 913  2.995       0.002        1        1    16.125     87.731
#
#                     TIME
# 913  2023-06-21 15:33:50
#
# 'PRES' = 1937.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 609       5        99           123         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC     PSAL  PSAL_ERROR  PSAL_QC  \
# 609            1  1937.4         2.4        1  34.7802        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 609  2.764       0.002        1        1    15.876      87.45
#
#                     TIME
# 609  2023-05-23 21:33:51
#
# 'PRES' = 1937.5
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 711       6        99           124         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 711            1  1937.5         2.4        1  34.78719        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 711  2.922       0.002        1        1    16.062     87.385
#
#                     TIME
# 711  2023-06-02 11:31:50
#
# 'PRES' = 1937.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 914       8        99           126         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 914            1  1937.6         2.4        1  34.78719        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 914  2.935       0.002        1        1    16.125     87.731
#
#                     TIME
# 914  2023-06-21 15:33:50
#
# 'PRES' = 1937.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 99        0        99           118         D         A          2902766
# 812       7        98           125         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 99             1  1937.8         2.4        1  34.78319        0.01        1
# 812            1  1937.8         2.4        1  34.78522        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 99   2.835       0.002        1        1    15.489     86.705
# 812  2.889       0.002        1        1    16.120     87.492
#
#                     TIME
# 99   2023-04-05 23:34:34
# 812  2023-06-12 01:28:50
#
# 'PRES' = 1937.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 201       1        99           119         D         A          2902766
# 303       2        99           120         D         A          2902766
# 405       3        99           121         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 201            1  1937.9         2.4        1  34.78618        0.01        1
# 303            1  1937.9         2.4        1  34.78722        0.01        1
# 405            1  1937.9         2.4        1  34.78322        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 201  2.921       0.002        1        1    15.669     87.042
# 303  2.934       0.002        1        1    15.592     87.388
# 405  2.842       0.002        1        1    15.456     87.650
#
#                     TIME
# 201  2023-04-15 13:32:47
# 303  2023-04-25 03:25:55
# 405  2023-05-04 17:39:25
#
# 'PRES' = 1938.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 507       4        99           122         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 507            1  1938.0         2.4        1  34.77818        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 507  2.714       0.002        1        1    15.652     87.637
#
#                     TIME
# 507  2023-05-14 07:38:50
#
# 'PRES' = 1962.5
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 712       6       100           124         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 712            1  1962.5         2.4        1  34.78421        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 712  2.874       0.002        1        1    16.062     87.385
#
#                     TIME
# 712  2023-06-02 11:31:50
#
# 'PRES' = 1962.7
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 100       0       100           118         D         A          2902766
# 406       3       100           121         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 100            1  1962.7         2.4        1  34.78117        0.01        1
# 406            1  1962.7         2.4        1  34.78024        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 100  2.788       0.002        1        1    15.489     86.705
# 406  2.787       0.002        1        1    15.456     87.650
#
#                     TIME
# 100  2023-04-05 23:34:34
# 406  2023-05-04 17:39:25
#
# 'PRES' = 1962.8
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 304       2       100           120         D         A          2902766
# 610       5       100           123         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 304            1  1962.8         2.4        1  34.78427        0.01        1
# 610            1  1962.8         2.4        1  34.77723        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 304  2.880       0.002        1        1    15.592     87.388
# 610  2.712       0.002        1        1    15.876     87.450
#
#                     TIME
# 304  2023-04-25 03:25:55
# 610  2023-05-23 21:33:51
#
# 'PRES' = 1962.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 813       7        99           125         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 813            1  1962.9         2.4        1  34.78317        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 813  2.834       0.002        1        1     16.12     87.492
#
#                     TIME
# 813  2023-06-12 01:28:50
#
# 'PRES' = 1963.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 915       8       100           126         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 915            1  1963.1         2.4        1  34.78518        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 915  2.886       0.002        1        1    16.125     87.731
#
#                     TIME
# 915  2023-06-21 15:33:50
#
# 'PRES' = 1963.3
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 508       4       100           122         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 508            1  1963.3         2.4        1  34.77612        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 508  2.669       0.002        1        1    15.652     87.637
#
#                     TIME
# 508  2023-05-14 07:38:50
#
# 'PRES' = 1963.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 202       1       100           119         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 202            1  1963.4         2.4        1  34.78422        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 202  2.874       0.002        1        1    15.669     87.042
#
#                     TIME
# 202  2023-04-15 13:32:47
#
# 'PRES' = 1978.4
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 101       0       101           118         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 101            1  1978.4         2.4        1  34.78002        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 101  2.761       0.002        1        1    15.489     86.705
#
#                     TIME
# 101  2023-04-05 23:34:34
#
# 'PRES' = 1979.5
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 305       2       101           120         D         A          2902766
# 814       7       100           125         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 305            1  1979.5         2.4        1  34.78304        0.01        1
# 814            1  1979.5         2.4        1  34.78202        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 305  2.835       0.002        1        1    15.592     87.388
# 814  2.806       0.002        1        1    16.120     87.492
#
#                     TIME
# 305  2023-04-25 03:25:55
# 814  2023-06-12 01:28:50
#
# 'PRES' = 1980.9
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 916       8       101           126         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 916            1  1980.9         2.4        1  34.78402        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 916  2.855       0.002        1        1    16.125     87.731
#
#                     TIME
# 916  2023-06-21 15:33:50
#
# 'PRES' = 1982.0
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 713       6       101           124         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 713            1  1982.0         2.4        1  34.78303        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 713  2.832       0.002        1        1    16.062     87.385
#
#                     TIME
# 713  2023-06-02 11:31:50
#
# 'PRES' = 1982.6
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 203       1       101           119         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 203            1  1982.6         2.4        1  34.78203        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 203  2.832       0.002        1        1    15.669     87.042
#
#                     TIME
# 203  2023-04-15 13:32:47
#
# 'PRES' = 1982.7
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 611       5       101           123         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 611            1  1982.7         2.4        1  34.77603        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 611  2.667       0.002        1        1    15.876      87.45
#
#                     TIME
# 611  2023-05-23 21:33:51
#
# 'PRES' = 1983.1
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 407       3       101           121         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 407            1  1983.1         2.4        1  34.77803        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 407  2.737       0.002        1        1    15.456      87.65
#
#                     TIME
# 407  2023-05-04 17:39:25
#
# 'PRES' = 1983.2
#      N_PROF  N_LEVELS  CYCLE_NUMBER DATA_MODE DIRECTION  PLATFORM_NUMBER  \
# 509       4       101           122         D         A          2902766
#
#      POSITION_QC    PRES  PRES_ERROR  PRES_QC      PSAL  PSAL_ERROR  PSAL_QC  \
# 509            1  1983.2         2.4        1  34.77502        0.01        1
#
#       TEMP  TEMP_ERROR  TEMP_QC  TIME_QC  LATITUDE  LONGITUDE  \
# 509  2.645       0.002        1        1    15.652     87.637
#
#                     TIME
# 509  2023-05-14 07:38:50

# %%
# Plot only a subsection of the larger plot

# Define the depth range 
min_depth = 0
max_depth = 250

# Filter the data for depths within the specified range
filtered_depths_range = [depth for depth in unique_depths if min_depth <= depth <= max_depth]
mean_salinity_range = [mean_salinity[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]
std_salinity_range = [std_salinity[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]
mean_temperature_range = [mean_temperature[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]
std_temperature_range = [std_temperature[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]
mean_density_range = [mean_density[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]
std_density_range = [std_density[i] for i, depth in enumerate(unique_depths) if min_depth <= depth <= max_depth]

plt.figure(figsize=(8, 6))
plt.plot(mean_salinity_range, filtered_depths_range, label='Mean Salinity')
plt.fill_betweenx(filtered_depths_range,
                  [m - s for m, s in zip(mean_salinity_range, std_salinity_range)],
                  [m + s for m, s in zip(mean_salinity_range, std_salinity_range)],
                  color='b', alpha=0.2, label='Salinity Std Dev')

plt.gca().invert_yaxis()
plt.xlabel('Salinity [PSU]')
plt.ylabel('Pressure [dbar]')
plt.title('Average Salinity Profile (within a range)')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(8, 6))
plt.plot(mean_temperature_range, filtered_depths_range, label='Mean Salinity')
plt.fill_betweenx(filtered_depths_range,
                  [m - s for m, s in zip(mean_temperature_range, std_salinity_range)],
                  [m + s for m, s in zip(mean_temperature_range, std_salinity_range)],
                  color='b', alpha=0.2, label='Salinity Std Dev')

plt.gca().invert_yaxis()
plt.xlabel('Temperature [deg C]')
plt.ylabel('Pressure [dbar]')
plt.title('Average Temperature Profile (within a range)')
plt.legend()
plt.grid(True)
plt.show()


plt.figure(figsize=(8, 6))
plt.plot(mean_density_range, filtered_depths_range, label='Mean Salinity')
plt.fill_betweenx(filtered_depths_range,
                  [m - s for m, s in zip(mean_density_range, std_salinity_range)],
                  [m + s for m, s in zip(mean_density_range, std_salinity_range)],
                  color='b', alpha=0.2, label='Salinity Std Dev')

plt.gca().invert_yaxis()
plt.xlabel('Density [kg/m^3]')
plt.ylabel('Pressure [dbar]')
plt.title('Average Density Profile (within a range)')
plt.legend()
plt.grid(True)
plt.show()

# %%
all_data = load_csv(filename)
# data = filter_one_float(all_data) # Work with one float
data=all_data # Or work with all floats
print(data['TIME'].head())
print(data['TIME'].tail()) #check we have the right season

# define pressure bins
max_pressure = data['PRES'].max()
print('Max pressure over the selected period is '+str(max_pressure)+' dbar')
pressure_bins = np.concatenate((
    np.arange(0, 10, 1),    # 1 dbar steps from 0 to 9 dbar
    np.arange(10, 200, 10),  # 1 dbar steps from 10 to 199 dbar
    np.arange(200, 2025, 25)  # 25 dbar steps from 200 to 2000 dbar
))

#assign each row to a pressure bin
data['PRES_BIN'] = pd.cut(data['PRES'], bins=pressure_bins, labels=pressure_bins[:-1])

#average inside each bin
data=data.groupby('PRES_BIN', observed=True).agg(
    avg_temp=('TEMP', 'mean'),
    avg_salinity=('PSAL', 'mean')
).reset_index()

print(data)
# Out:
# Number of rows in data: 917
# 0    2023-04-05 23:34:34
# 1    2023-04-05 23:34:34
# 2    2023-04-05 23:34:34
# 3    2023-04-05 23:34:34
# 4    2023-04-05 23:34:34
# Name: TIME, dtype: object
# 912    2023-06-21 15:33:50
# 913    2023-06-21 15:33:50
# 914    2023-06-21 15:33:50
# 915    2023-06-21 15:33:50
# 916    2023-06-21 15:33:50
# Name: TIME, dtype: object
# Max pressure over the selected period is 1983.2 dbar
#     PRES_BIN   avg_temp  avg_salinity
# 0          0  30.205538     32.641167
# 1          1  30.045100     32.676876
# 2          2  29.804556     32.881949
# 3          3  30.221667     32.556757
# 4          4  30.033300     32.737476
# ..       ...        ...           ...
# 96      1875   2.976222     34.789009
# 97      1900   2.918444     34.786338
# 98      1925   2.861778     34.784199
# 99      1950   2.811556     34.781757
# 100     1975   2.774444     34.780360
#
# [101 rows x 3 columns]

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['avg_temp'], data['PRES_BIN'])

# Step 4: Customizing the plot
plt.gca().invert_yaxis()  # Invert the y-axis so the surface is at the top
plt.xlabel('Temperature (°C)')
plt.ylabel('Pressure Bin')
plt.title(f'Binned temperature for '+season)
plt.ylim(100,0)
# Display the plot
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['avg_salinity'], data['PRES_BIN'])

# Step 4: Customizing the plot
plt.gca().invert_yaxis()  # Invert the y-axis so the surface is at the top
plt.xlabel('Salinity (°C)')
plt.ylabel('Pressure Bin')
plt.title(f'Binned salinity for '+season)
plt.ylim(100,0)
# Display the plot
plt.show()
